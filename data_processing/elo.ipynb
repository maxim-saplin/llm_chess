# %% [markdown]
# # Preparing Input Data
#
# Win rates need to be aggregated across different sources:
# 1. Newer Logs
#     1. `data_processing/refined.csv` - LLMs as Black playing against Random Player. The key data source for all models to be rated and included in the LB
#     2. `data_processing/dragon_refined.csv` - LLMs as Black playing against different levels of Komodo Dragon chess engine (Elo rated against chess.com pool)
# 2. Older Logs
#     1. `_logs/_pre_aug_2025/dragon_vs_llm` - LLMs as Black playing against different levels of Komodo Dragon chess engine (Elo rated against chess.com pool)
#     2. `_logs/_pre_aug_2025/misc/dragon` - different levels of dragon playing different colors vs Random Player and Stockfish
#     3. `_logs/_pre_aug_2025/llm_vs_llm` - LLMs vs LLMs
#
# ## Dataset Structure
#
# - player_white - model name or one of the values: 'random_player', 'dragon-lvl-X' (where X is integer in range from 1 to 25), 'stockfish-lvl-X' (where X is integer in range from 0 to 20)
# - player_black - same as white values, denotes all games as black
# - games - total games the given white/black couple had
# - win_rate_white - percent of the games won by the white player
# - win_rate_black - same for black
# - draw_rate - percent of Draws
# - player_black_elo - only valid for Dragon levels (e.g. lvl 1 is 250, lvl 2 is 375, lvl 3 is 500 etc.), empty for other (non rated) players
# - player_white_elo - same as above
# - source - indicates which data source this row came from: 'refined', 'dragon_refined', 'dragon_vs_llm', 'misc_dragon', 'llm_vs_llm'

# %%
import csv
import json
from pathlib import Path
import re
from collections import defaultdict, Counter
from prettytable import PrettyTable

# Paths
REFINED_CSV = Path(".") / "refined.csv"
DRAGON_REFINED_CSV = Path(".") / "dragon_refined.csv"
WIN_RATES_CSV = Path(".") / "win_rates.csv"
DRAGON_VS_LLM_DIR = Path("..") / "_logs" / "_pre_aug_2025" / "dragon_vs_llm"
MISC_DRAGON_DIR = Path("..") / "_logs" / "_pre_aug_2025" / "misc" / "dragon"
LLM_VS_LLM_DIR = Path("..") / "_logs" / "_pre_aug_2025" / "llm_vs_llm"

# Prepare output header as per dataset specification
HEADER = [
    "player_white",
    "player_black",
    "games",
    "win_rate_white",
    "win_rate_black",
    "draw_rate",
    "player_white_elo",
    "player_black_elo",
    "source",
]

CURR_ROWS = 0

ROWS_OUT = []

# Counters per source
refined_count = 0
dragon_refined_count = 0
dragon_vs_llm_count = 0
misc_dragon_count = 0
llm_vs_llm_count = 0

# Helper functions
def dragon_elo(level):
    """Calculate Dragon Elo: lvl 1 = 250, lvl 2 = 375, etc."""
    return 250 + 125 * (level - 1)

def parse_dragon_level(name):
    """Extract dragon level from name like 'dragon-lvl-1' or 'lvl-1'"""
    match = re.search(r'lvl-(\d+)', name)
    return int(match.group(1)) if match else None

def read_aggregate_json(json_path):
    """Read _aggregate_results.json and return game stats"""
    with open(json_path, 'r') as f:
        data = json.load(f)
    return {
        'total_games': data['total_games'],
        'white_wins': data['white_wins'],
        'black_wins': data['black_wins'],
        'draws': data['draws']
    }

def compute_win_rates(white_wins, black_wins, draws, total_games):
    """Compute win rates as percentages"""
    if white_wins + black_wins + draws != total_games:
        raise ValueError(f"Inconsistent game counts: {white_wins} + {black_wins} + {draws} != {total_games}")
    
    win_rate_white = round(white_wins * 100.0 / total_games, 3)
    win_rate_black = round(black_wins * 100.0 / total_games, 3)
    draw_rate = round(draws * 100.0 / total_games, 3)
    
    return win_rate_white, win_rate_black, draw_rate

def preview_win_rates(rows_or_csv, preview_top=3, preview_bottom=5):
    """
    Print a pretty table preview of the win rates.
    Accepts either a path to a CSV file, a list of rows (with header as first row),
    or a list of dicts (all with identical keys).
    Shows top N rows, ellipsis if more than (top+bottom), and bottom M rows.
    Returns (rows, header).
    """
    # Determine if input is a path or already rows
    if hasattr(rows_or_csv, "open"):  # likely a Path
        with rows_or_csv.open("r", newline="") as f:
            reader = list(csv.reader(f))
            header = reader[0]
            rows = reader[1:]
    elif isinstance(rows_or_csv, list):
        if not rows_or_csv:
            print("No data to preview.")
            return [], []
        if isinstance(rows_or_csv[0], dict):
            header = list(rows_or_csv[0].keys())
            rows = [[row.get(col, "") for col in header] for row in rows_or_csv]
        else:
            header = rows_or_csv[0]
            rows = rows_or_csv[1:]
    else:
        raise ValueError("Input must be a Path, a list of rows (with header as first row), or a list of dicts")

    table = PrettyTable()
    table.field_names = header

    # Show top N rows if exists
    for i in range(min(preview_top, len(rows))):
        table.add_row(rows[i])

    # Add three dots row if there are more than (top+bottom) rows
    if len(rows) > (preview_top + preview_bottom):
        table.add_row(['...'] * len(header))

    # Add bottom M rows (or all remaining if less than M)
    for row in rows[-preview_bottom:]:
        table.add_row(row)

    print(table)
    return rows, header

# %% [markdown]
# ## Ingesting Data
#
# ### 1. `refined.csv`

# %% [markdown]
# ### 2. `dragon_refined.csv`

# %%
# Ingest refined.csv (LLM as Black vs Random Player)
with REFINED_CSV.open("r", newline="") as f:
    reader = csv.DictReader(f)
    for row in reader:
        total_games = int(row["total_games"])
        player_wins = int(row["player_wins"])
        opponent_wins = int(row["opponent_wins"])
        draws = int(row["draws"])

        # Basic sanity check
        if player_wins + opponent_wins + draws != total_games:
            raise ValueError(
                f"Row for player {row['Player']} has inconsistent win/loss/draw counts"
            )

        # Compute win rates as percentages (0-100)
        win_rate_white = round(opponent_wins * 100.0 / total_games, 3)
        win_rate_black = round(player_wins * 100.0 / total_games, 3)
        draw_rate = round(draws * 100.0 / total_games, 3)

        ROWS_OUT.append(
            {
                "player_white": "random_player",
                "player_black": row["Player"],
                "games": total_games,
                "win_rate_white": win_rate_white,
                "win_rate_black": win_rate_black,
                "draw_rate": draw_rate,
                "player_white_elo": "",
                "player_black_elo": "",
                "source": "refined",
            }
        )
        refined_count += 1

print(f"Loaded {refined_count} rows from refined.csv")

preview_win_rates(ROWS_OUT)
# Out:
# Loaded 122 rows from refined.csv
# +---------------+------------------------------------+-------+----------------+----------------+-----------+------------------+------------------+---------+
# |  player_white |            player_black            | games | win_rate_white | win_rate_black | draw_rate | player_white_elo | player_black_elo |  source |
# +---------------+------------------------------------+-------+----------------+----------------+-----------+------------------+------------------+---------+
# | random_player |        gpt-5-2025-08-07-low        |   43  |      0.0       |     95.349     |   4.651   |                  |                  | refined |
# | random_player |     gpt-5-mini-2025-08-07-high     |   35  |      0.0       |     88.571     |   11.429  |                  |                  | refined |
# | random_player |         o3-2025-04-16-low          |   42  |     2.381      |     90.476     |   7.143   |                  |                  | refined |
# |      ...      |                ...                 |  ...  |      ...       |      ...       |    ...    |       ...        |       ...        |   ...   |
# | random_player |         gpt-35-turbo-0125          |   30  |     100.0      |      0.0       |    0.0    |                  |                  | refined |
# | random_

#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'deepseek-chat-v3',
#    70,
#    97.143,
#    0.0,
#    2.857,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-2.0-flash-lite-preview-02-05',
#    39,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-2.0-flash-thinking-exp-01-21',
#    33,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'claude-v3-haiku', 40, 100.0, 0.0, 0.0, '', '', 'refined'],
#   ['random_player',
#    'gemma-3-12b-it@iq4_xs',
#    134,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'chat-bison-32k@002',
#    36,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen3-14b@iq4_xs-thinking',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'qwq-32b', 33, 100.0, 0.0, 0.0, '', '', 'refined'],
#   ['random_player',
#    'qwen3-32b-cerebras-thinking',
#    47,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'mistral-small-24b-instruct-2501@q4_k_m',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen-turbo-2024-11-01',
#    33,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemma-3-12b-it@q8_0',
#    67,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'llama3-8b-8192', 60, 100.0, 0.0, 0.0, '', '', 'refined'],
#   ['random_player',
#    'gemma2-9b-it-groq',
#    35,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'sky-t1-32b-preview',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-4.1-nano-2025-04-14',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen2.5-14b-instruct@q8_0',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'amazon.nova-pro-v1',
#    33,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'mercury-coder-small',
#    60,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemma-3-27b-it@iq4_xs',
#    67,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen2.5-7b-instruct-1m',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'magistral-small-2506',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'ministral-8b-instruct-2410',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'mistral-small-instruct-2409',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwq-32b-preview@q4_k_m',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'phi-4', 30, 100.0, 0.0, 0.0, '', '', 'refined'],
#   ['random_player',
#    'qwen2.5-14b-instruct-1m',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'mistral-nemo-12b-instruct-2407',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'amazon.nova-lite-v1',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-35-turbo-0613',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'granite-3.1-8b-instruct',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-35-turbo-1106',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'internlm3-8b-instruct',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'llama-3.1-tulu-3-8b@q8_0',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'deepseek-r1-distill-qwen-32b@q4_k_m',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'deephermes-3-llama-3-8b-preview@q8',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-35-turbo-0125',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'deepseek-r1-distill-qwen-14b@q8_0',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-2.0-flash-thinking-exp-1219',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-35-turbo-0301',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'llama-2-7b-chat',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined']],
#  ['player_white',
#   'player_black',
#   'games',
#   'win_rate_white',
#   'win_rate_black',
#   'draw_rate',
#   'player_white_elo',
#   'player_black_elo',
#   'source'])

# %%
# Ingest dragon_refined.csv (LLMs as Black vs Dragon levels)
if DRAGON_REFINED_CSV.exists():
    with DRAGON_REFINED_CSV.open("r", newline="") as f:
        reader = csv.DictReader(f)
        for row in reader:
            total_games = int(row["total_games"])
            player_wins = int(row["player_wins"])  # LLM (Black) wins
            opponent_wins = int(row["opponent_wins"])  # Dragon (White) wins
            draws = int(row["draws"])

            # Sanity check
            if player_wins + opponent_wins + draws != total_games:
                raise ValueError(
                    f"Row for player {row['Player']} has inconsistent counts"
                )

            # The opponent in these rows is a dragon level (column name has a known typo: 'white_opponent')
            white_name = (
                row.get("white_opponent")
                or row.get("white_opponent")
                or row.get("opponent")
                or row.get("Opponent")
                or ""
            )
            dragon_level = parse_dragon_level(white_name)
            player_name = row.get("Player") or row.get("player")

            # Compute win rates
            win_rate_white = round(opponent_wins * 100.0 / total_games, 3)  # Dragon as White
            win_rate_black = round(player_wins * 100.0 / total_games, 3)    # LLM as Black
            draw_rate = round(draws * 100.0 / total_games, 3)

            # Resolve player_white label and Elo
            player_white = f"dragon-lvl-{dragon_level}" if dragon_level is not None else white_name
            player_white_elo = dragon_elo(dragon_level) if dragon_level is not None else ""

            ROWS_OUT.append(
                {
                    "player_white": player_white,
                    "player_black": player_name,
                    "games": total_games,
                    "win_rate_white": win_rate_white,
                    "win_rate_black": win_rate_black,
                    "draw_rate": draw_rate,
                    "player_white_elo": player_white_elo,
                    "player_black_elo": "",
                    "source": "dragon_refined",
                }
            )
            dragon_refined_count += 1

print(f"Loaded {dragon_refined_count} rows from dragon_refined.csv")
# Out:
# Loaded 43 rows from dragon_refined.csv

# %%
with REFINED_CSV.open("r", newline="") as f:
    reader = csv.DictReader(f)
    for row in reader:
        total_games = int(row["total_games"])
        player_wins = int(row["player_wins"])
        opponent_wins = int(row["opponent_wins"])
        draws = int(row["draws"])

        # Basic sanity check
        if player_wins + opponent_wins + draws != total_games:
            raise ValueError(
                f"Row for player {row['Player']} has inconsistent win/loss/draw counts"
            )

        # Compute win rates as percentages (0-100)
        win_rate_white = round(opponent_wins * 100.0 / total_games, 3)
        win_rate_black = round(player_wins * 100.0 / total_games, 3)
        draw_rate = round(draws * 100.0 / total_games, 3)

        ROWS_OUT.append(
            {
                "player_white": "random_player",
                "player_black": row["Player"],
                "games": total_games,
                "win_rate_white": win_rate_white,
                "win_rate_black": win_rate_black,
                "draw_rate": draw_rate,
                "player_white_elo": "",
                "player_black_elo": "",
                "source": "refined",
            }
        )

print(f"Loaded {len(ROWS_OUT)} rows from refined.csv")

preview_win_rates(ROWS_OUT)
# Out:
# Loaded 287 rows from refined.csv
# +---------------+------------------------------------+-------+----------------+----------------+-----------+------------------+------------------+---------+
# |  player_white |            player_black            | games | win_rate_white | win_rate_black | draw_rate | player_white_elo | player_black_elo |  source |
# +---------------+------------------------------------+-------+----------------+----------------+-----------+------------------+------------------+---------+
# | random_player |        gpt-5-2025-08-07-low        |   43  |      0.0       |     95.349     |   4.651   |                  |                  | refined |
# | random_player |     gpt-5-mini-2025-08-07-high     |   35  |      0.0       |     88.571     |   11.429  |                  |                  | refined |
# | random_player |         o3-2025-04-16-low          |   42  |     2.381      |     90.476     |   7.143   |                  |                  | refined |
# |      ...      |                ...                 |  ...  |      ...       |      ...       |    ...    |       ...        |       ...        |   ...   |
# | random_player |         gpt-35-turbo-0125          |   30  |     100.0      |      0.0       |    0.0    |                  |                  | refined |
# | random_player | deepseek-r1-distill-qwen-14b@q8_0  |   30  |     100.0      |      0.0       |    0.0    |                  |                  | refined |
# | random_player | gemini-2.0-flash-thinking-exp-1219 |   30  |     100.0      |      0.0       |    0.0    |                  |                  | refined |
# | random_player |         gpt-35-turbo-0301          |   30  |     100.0      |      0.0       |    0.0    |                  |                  | refined |
# | random_player |          llama-2-7b-chat           |   30  |     100.0      |      0.0       |    0.0    |                  |                  | refined |
# +---------------+------------------------------------+-------+----------------+----------------+-----------+------------------+------------------+---------+
# ([['random_player',
#    'gpt-5-2025-08-07-low',
#    43,
#    0.0,
#    95.349,
#    4.651,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-5-mini-2025-08-07-high',
#    35,
#    0.0,
#    88.571,
#    11.429,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'o3-2025-04-16-low',
#    42,
#    2.381,
#    90.476,
#    7.143,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-5-nano-2025-08-07-medium',
#    33,
#    3.03,
#    90.909,
#    6.061,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'o4-mini-2025-04-16-high',
#    39,
#    2.564,
#    89.744,
#    7.692,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-5-nano-2025-08-07-high',
#    33,
#    3.03,
#    87.879,
#    9.091,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-5-mini-2025-08-07-medium',
#    33,
#    0.0,
#    81.818,
#    18.182,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'o3-2025-04-16-medium',
#    53,
#    9.434,
#    90.566,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'o1-2024-12-17-medium',
#    41,
#    2.439,
#    80.488,
#    17.073,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'grok-3-mini-beta-high',
#    49,
#    0.0,
#    71.429,
#    28.571,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'o4-mini-2025-04-16-medium',
#    159,
#    0.0,
#    68.553,
#    31.447,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'non-gemini-25pro-t03_mini41-t00_mini41-t03',
#    45,
#    0.0,
#    57.778,
#    42.222,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'o1-2024-12-17-low',
#    47,
#    0.0,
#    57.447,
#    42.553,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'o4-mini-2025-04-16-low',
#    74,
#    1.351,
#    43.243,
#    55.405,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'claude-v4
0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-oss-120b-medium',
#    43,
#    69.767,
#    25.581,
#    4.651,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-oss-120b-high',
#    43,
#    72.093,
#    27.907,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-oss-20b-high',
#    33,
#    48.485,
#    3.03,
#    48.485,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-oss-120b-low',
#    46,
#    67.391,
#    19.565,
#    13.043,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'llama-3-70b-instruct-awq',
#    30,
#    50.0,
#    0.0,
#    50.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-2.5-flash',
#    42,
#    71.429,
#    19.048,
#    9.524,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-oss-20b-low',
#    33,
#    57.576,
#    3.03,
#    39.394,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-2.0-flash-001',
#    67,
#    61.194,
#    4.478,
#    34.328,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'grok-2-1212',
#    49,
#    65.306,
#    4.082,
#    30.612,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'non-haiku35-t07_haiku35-t10_haiku35-t03',
#    42,
#    66.667,
#    0.0,
#    33.333,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-1.5-flash-001',
#    30,
#    66.667,
#    0.0,
#    33.333,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemma-2-27b-it@q6_k_l',
#    30,
#    73.333,
#    0.0,
#    26.667,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'llama-4-scout-cerebras',
#    39,
#    79.487,
#    0.0,
#    20.513,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemma-2-9b-it-8bit',
#    30,
#    86.667,
#    0.0,
#    13.333,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'deepseek-chat-v3-0324',
#    45,
#    91.111,
#    2.222,
#    6.667,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'llama-3.3-70b',
#    42,
#    90.476,
#    0.0,
#    9.524,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen-plus-2025-01-25',
#    33,
#    90.909,
#    0.0,
#    9.091,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen3-4b-thinking-2507@q8',
#    37,
#    91.892,
#    0.0,
#    8.108,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-1.5-pro-preview-0409',
#    40,
#    92.5,
#    0.0,
#    7.5,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-2.0-flash-exp',
#    30,
#    93.333,
#    0.0,
#    6.667,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen2.5-72b-instruct',
#    30,
#    93.333,
#    0.0,
#    6.667,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'kimi-k2-instruct',
#    33,
#    96.97,
#    3.03,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'llama3.1-8b', 90, 96.667, 0.0, 3.333, '', '', 'refined'],
#   ['random_player',
#    'gemini-2.0-flash-lite-001',
#    66,
#    98.485,
#    1.515,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'deepseek-chat-v3',
#    70,
#    97.143,
#    0.0,
#    2.857,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-2.0-flash-lite-preview-02-05',
#    39,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-2.0-flash-thinking-exp-01-21',
#    33,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'claude-v3-haiku', 40, 100.0, 0.0, 0.0, '', '', 'refined'],
#   ['random_player',
#    'gemma-3-12b-it@iq4_xs',
#    134,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'chat-bison-32k@002',
#    36,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen3-14b@iq4_xs-thinking',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'qwq-32b', 33, 100.0, 0.0, 0.0, '', '', 'refined'],
#   ['random_player',
#    'qwen3-32b-cerebras-thinking',
#    47,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'mistral-small-24b-instruct-2501@q4_k_m',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen-turbo-2024-11-01',
#    33,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemma-3-12b-it@q8_0',
#    67,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'llama3-8b-8192', 60, 100.0, 0.0, 0.0, '', '', 'refined'],
#   ['random_player',
#    'gemma2-9b-it-groq',
#    35,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'sky-t1-32b-preview',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-4.1-nano-2025-04-14',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen2.5-14b-instruct@q8_0',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'amazon.nova-pro-v1',
#    33,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'mercury-coder-small',
#    60,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemma-3-27b-it@iq4_xs',
#    67,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen2.5-7b-instruct-1m',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'magistral-small-2506',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'ministral-8b-instruct-2410',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'mistral-small-instruct-2409',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwq-32b-preview@q4_k_m',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'phi-4', 30, 100.0, 0.0, 0.0, '', '', 'refined'],
#   ['random_player',
#    'qwen2.5-14b-instruct-1m',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'mistral-nemo-12b-instruct-2407',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'amazon.nova-lite-v1',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-35-turbo-0613',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'granite-3.1-8b-instruct',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-35-turbo-1106',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'internlm3-8b-instruct',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'llama-3.1-tulu-3-8b@q8_0',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'deepseek-r1-distill-qwen-32b@q4_k_m',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'deephermes-3-llama-3-8b-preview@q8',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-35-turbo-0125',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'deepseek-r1-distill-qwen-14b@q8_0',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-2.0-flash-thinking-exp-1219',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-35-turbo-0301',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'llama-2-7b-chat', 30, 100.0, 0.0, 0.0, '', '', 'refined'],
#   ['dragon-lvl-3',
#    'gpt-5-nano-2025-08-07-medium',
#    33,
#    51.515,
#    27.273,
#    21.212,
#    500,
#    '',
#    'dragon_refined'],
#   ['dragon-lvl-3',
#    'o3-mini-2025-01-31-high',
#    33,
#    12.121,
#    15.152,
#    72.727,
#    500,
#    '',
#    'dragon_refined'],
#   ['dragon-lvl

#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen-plus-2025-01-25',
#    33,
#    90.909,
#    0.0,
#    9.091,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen3-4b-thinking-2507@q8',
#    37,
#    91.892,
#    0.0,
#    8.108,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-1.5-pro-preview-0409',
#    40,
#    92.5,
#    0.0,
#    7.5,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-2.0-flash-exp',
#    30,
#    93.333,
#    0.0,
#    6.667,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen2.5-72b-instruct',
#    30,
#    93.333,
#    0.0,
#    6.667,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'kimi-k2-instruct',
#    33,
#    96.97,
#    3.03,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'llama3.1-8b', 90, 96.667, 0.0, 3.333, '', '', 'refined'],
#   ['random_player',
#    'gemini-2.0-flash-lite-001',
#    66,
#    98.485,
#    1.515,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'deepseek-chat-v3',
#    70,
#    97.143,
#    0.0,
#    2.857,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-2.0-flash-lite-preview-02-05',
#    39,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-2.0-flash-thinking-exp-01-21',
#    33,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'claude-v3-haiku', 40, 100.0, 0.0, 0.0, '', '', 'refined'],
#   ['random_player',
#    'gemma-3-12b-it@iq4_xs',
#    134,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'chat-bison-32k@002',
#    36,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen3-14b@iq4_xs-thinking',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'qwq-32b', 33, 100.0, 0.0, 0.0, '', '', 'refined'],
#   ['random_player',
#    'qwen3-32b-cerebras-thinking',
#    47,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'mistral-small-24b-instruct-2501@q4_k_m',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen-turbo-2024-11-01',
#    33,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemma-3-12b-it@q8_0',
#    67,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'llama3-8b-8192', 60, 100.0, 0.0, 0.0, '', '', 'refined'],
#   ['random_player',
#    'gemma2-9b-it-groq',
#    35,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'sky-t1-32b-preview',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-4.1-nano-2025-04-14',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen2.5-14b-instruct@q8_0',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'amazon.nova-pro-v1',
#    33,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'mercury-coder-small',
#    60,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemma-3-27b-it@iq4_xs',
#    67,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwen2.5-7b-instruct-1m',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'magistral-small-2506',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'ministral-8b-instruct-2410',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'mistral-small-instruct-2409',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'qwq-32b-preview@q4_k_m',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player', 'phi-4', 30, 100.0, 0.0, 0.0, '', '', 'refined'],
#   ['random_player',
#    'qwen2.5-14b-instruct-1m',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'mistral-nemo-12b-instruct-2407',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'amazon.nova-lite-v1',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-35-turbo-0613',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'granite-3.1-8b-instruct',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-35-turbo-1106',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'internlm3-8b-instruct',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'llama-3.1-tulu-3-8b@q8_0',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'deepseek-r1-distill-qwen-32b@q4_k_m',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'deephermes-3-llama-3-8b-preview@q8',
#    42,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-35-turbo-0125',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'deepseek-r1-distill-qwen-14b@q8_0',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gemini-2.0-flash-thinking-exp-1219',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'gpt-35-turbo-0301',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined'],
#   ['random_player',
#    'llama-2-7b-chat',
#    30,
#    100.0,
#    0.0,
#    0.0,
#    '',
#    '',
#    'refined']],
#  ['player_white',
#   'player_black',
#   'games',
#   'win_rate_white',
#   'win_rate_black',
#   'draw_rate',
#   'player_white_elo',
#   'player_black_elo',
#   'source'])

# %% [markdown]
# ### 2. `_logs/dragon_vs_llm` - Dragon (White) vs LLM (Black)

# %%
# Process dragon_vs_llm directory
dragon_vs_llm_count = 0

if DRAGON_VS_LLM_DIR.exists():
    for pair_dir in DRAGON_VS_LLM_DIR.iterdir():
        if not pair_dir.is_dir():
            continue
        
        # Skip error/fail directories
        if pair_dir.name.startswith(('errors-', 'fails-')):
            continue
        
        # Parse directory name: lvl-X_vs_Y
        if '_vs_' not in pair_dir.name:
            continue
        
        white_part, black_part = pair_dir.name.split('_vs_', 1)
        
        # Extract dragon level
        dragon_level = parse_dragon_level(white_part)
        if dragon_level is None:
            continue
        
        # Aggregate across all timestamp directories
        total_games = 0
        total_white_wins = 0
        total_black_wins = 0
        total_draws = 0
        
        for timestamp_dir in pair_dir.iterdir():
            if not timestamp_dir.is_dir():
                continue
            
            aggregate_file = timestamp_dir / "_aggregate_results.json"
            if aggregate_file.exists():
                stats = read_aggregate_json(aggregate_file)
                total_games += stats['total_games']
                total_white_wins += stats['white_wins']
                total_black_wins += stats['black_wins']
                total_draws += stats['draws']
        
        # Skip if no games found
        if total_games == 0:
            continue
        
        # Compute win rates
        win_rate_white, win_rate_black, draw_rate = compute_win_rates(
            total_white_wins, total_black_wins, total_draws, total_games
        )
        
        # Add row
        ROWS_OUT.append({
            "player_white": f"dragon-lvl-{dragon_level}",
            "player_black": black_part,
            "games": total_games,
            "win_rate_white": win_rate_white,
            "win_rate_black": win_rate_black,
            "draw_rate": draw_rate,
            "player_white_elo": dragon_elo(dragon_level),
            "player_black_elo": "",
            "source": "dragon_vs_llm",
        })
        
        dragon_vs_llm_count += 1

print(f"Loaded {dragon_vs_llm_count} rows from dragon_vs_llm")
# Out:
# Loaded 28 rows from dragon_vs_llm

# %% [markdown]
# ### 3. `_logs/misc/dragon` - Pre-aggregated Dragon vs Stockfish/Random

# %%
# Process misc/dragon directory
misc_dragon_count = 0

if MISC_DRAGON_DIR.exists():
    for json_file in MISC_DRAGON_DIR.glob("*.json"):
        # Parse filename: white_vs_black.json
        filename = json_file.stem
        if '_vs_' not in filename:
            continue
        
        white_name, black_name = filename.split('_vs_', 1)
        
        # Read the aggregated data
        stats = read_aggregate_json(json_file)
        
        # Compute win rates
        win_rate_white, win_rate_black, draw_rate = compute_win_rates(
            stats['white_wins'], stats['black_wins'], stats['draws'], stats['total_games']
        )
        
        # Determine Elo ratings
        white_elo = ""
        black_elo = ""
        
        # Check if white is dragon
        white_dragon_level = parse_dragon_level(white_name)
        if white_dragon_level is not None:
            white_elo = dragon_elo(white_dragon_level)
        
        # Check if black is dragon
        black_dragon_level = parse_dragon_level(black_name)
        if black_dragon_level is not None:
            black_elo = dragon_elo(black_dragon_level)
        
        # Add row
        ROWS_OUT.append({
            "player_white": white_name,
            "player_black": black_name,
            "games": stats['total_games'],
            "win_rate_white": win_rate_white,
            "win_rate_black": win_rate_black,
            "draw_rate": draw_rate,
            "player_white_elo": white_elo,
            "player_black_elo": black_elo,
            "source": "misc_dragon",
        })
        
        misc_dragon_count += 1

print(f"Loaded {misc_dragon_count} rows from misc/dragon")
# Out:
# Loaded 20 rows from misc/dragon

# %% [markdown]
# ### 4. `_logs/llm_vs_llm` - LLM vs LLM

# %%
# Process llm_vs_llm directory
llm_vs_llm_count = 0

if LLM_VS_LLM_DIR.exists():
    for pair_dir in LLM_VS_LLM_DIR.iterdir():
        if not pair_dir.is_dir():
            continue
        
        # Parse directory name: white_vs_black
        if '_vs_' not in pair_dir.name:
            continue
        
        white_name, black_name = pair_dir.name.split('_vs_', 1)
        
        # Aggregate across all timestamp directories
        total_games = 0
        total_white_wins = 0
        total_black_wins = 0
        total_draws = 0
        
        for timestamp_dir in pair_dir.iterdir():
            if not timestamp_dir.is_dir():
                continue
            
            aggregate_file = timestamp_dir / "_aggregate_results.json"
            if aggregate_file.exists():
                stats = read_aggregate_json(aggregate_file)
                total_games += stats['total_games']
                total_white_wins += stats['white_wins']
                total_black_wins += stats['black_wins']
                total_draws += stats['draws']
        
        # Skip if no games found
        if total_games == 0:
            continue
        
        # Compute win rates
        win_rate_white, win_rate_black, draw_rate = compute_win_rates(
            total_white_wins, total_black_wins, total_draws, total_games
        )
        
        # Add row (no Elo for LLM vs LLM)
        ROWS_OUT.append({
            "player_white": white_name,
            "player_black": black_name,
            "games": total_games,
            "win_rate_white": win_rate_white,
            "win_rate_black": win_rate_black,
            "draw_rate": draw_rate,
            "player_white_elo": "",
            "player_black_elo": "",
            "source": "llm_vs_llm",
        })
        
        llm_vs_llm_count += 1

print(f"Loaded {llm_vs_llm_count} rows from llm_vs_llm")
# Out:
# Loaded 11 rows from llm_vs_llm

# %% [markdown]
# ## Data Analysis and Model Name Standardization

# %%
# Collect all unique model names from all sources
all_model_names = set()

for row in ROWS_OUT:
    # Skip non-LLM players
    if row['player_white'] not in ['random_player'] and not row['player_white'].startswith(('dragon-lvl-', 'stockfish-lvl-')):
        all_model_names.add(row['player_white'])
    if row['player_black'] not in ['random_player'] and not row['player_black'].startswith(('dragon-lvl-', 'stockfish-lvl-')):
        all_model_names.add(row['player_black'])

print(f"Found {len(all_model_names)} unique model names across all sources:")
print("=" * 60)

# Group by data source
models_by_source = defaultdict(set)
for row in ROWS_OUT:
    source = row['source']
    if row['player_white'] not in ['random_player'] and not row['player_white'].startswith(('dragon-lvl-', 'stockfish-lvl-')):
        models_by_source[source].add(row['player_white'])
    if row['player_black'] not in ['random_player'] and not row['player_black'].startswith(('dragon-lvl-', 'stockfish-lvl-')):
        models_by_source[source].add(row['player_black'])

for source, models in models_by_source.items():
    print(f"\n{source.upper()} ({len(models)} models):")
    for model in sorted(models):
        print(f"  - {model}")

print("\n" + "=" * 60)
# Out:
# Found 147 unique model names across all sources:
# ============================================================
#
# REFINED (122 models):
#   - amazon.nova-lite-v1
#   - amazon.nova-pro-v1
#   - chat-bison-32k@002
#   - claude-v3-5-haiku
#   - claude-v3-5-sonnet-v1
#   - claude-v3-5-sonnet-v2
#   - claude-v3-7-sonnet
#   - claude-v3-7-sonnet-thinking_10000
#   - claude-v3-7-sonnet-thinking_1024
#   - claude-v3-7-sonnet-thinking_2048
#   - claude-v3-7-sonnet-thinking_5000
#   - claude-v3-haiku
#   - claude-v3-opus
#   - claude-v4-opus
#   - claude-v4-opus-thinking_16000
#   - claude-v4-sonnet
#   - claude-v4-sonnet-thinking_16000
#   - deephermes-3-llama-3-8b-preview@q8
#   - deepseek-chat-v3
#   - deepseek-chat-v3-0324
#   - deepseek-r1-distill-qwen-14b@q8_0
#   - deepseek-r1-distill-qwen-32b@q4_k_m
#   - deepseek-reasoner-r1
#   - gemini-1.5-flash-001
#   - gemini-1.5-pro-preview-0409
#   - gemini-2.0-flash-001
#   - gemini-2.0-flash-exp
#   - gemini-2.0-flash-lite-001
#   - gemini-2.0-flash-lite-preview-02-05
#   - gemini-2.0-flash-thinking-exp-01-21
#   - qwen3-14b@iq4_xs-thinking
#   - qwen3-30b-a3b-thinking-2507@q4_k_m
#   - qwen3-32b-cerebras-thinking
#   - qwen3-4b-thinking-2507@q8
#   - qwq-32b
#   - qwq-32b-preview@q4_k_m
#   - sky-t1-32b-preview
#
# DRAGON_REFINED (20 models):
#   - N/A
#   - claude-3-7-sonnet-20250219-thinking-budget-10000
#   - claude-3-7-sonnet-20250219-thinking-budget-5000
#   - gpt-5-nano-2025-08-07-high
#   - gpt-5-nano-2025-08-07-low
#   - gpt-5-nano-2025-08-07-medium
#   - grok-3-mini-beta-high
#   - grok-3-mini-fast-beta-high
#   - o1-2024-12-17
#   - o1-mini-2024-09-12
#   - o3-2025-04-16-low
#   - o3-2025-04-16-medium_timeout-60m
#   - o3-mini-2025-01-31-high
#   - o3-mini-2025-01-31-low
#   - o3-mini-2025-01-31-medium
#   - o4-mini-2025-04-16-high
#   - o4-mini-2025-04-16-high_timeout-20m
#   - o4-mini-2025-04-16-high_timeout-60m
#   - o4-mini-2025-04-16-low
#   - o4-mini-2025-04-16-medium
#
# DRAGON_VS_LLM (17 models):
#   - 3x-o4-mini-2025-04-16-low_41mini-t03
#   - 3x-o4-mini-2025-04-16-low_o4-mini-2025-04-16-medium
#   - 5x-o4-mini-2025-04-16-low_o4-mini-2025-04-16-medium
#   - claude-3-7-sonnet-20250219-thinking-budget-10000
#   - claude-3-7-sonnet-20250219-thinking-budget-5000
#   - gemini-25pro-t03_mini41-t00_mini41-t03
#   - grok-3-mini-beta-high
#   - grok-3-mini-fast-beta-high
#   - o3-2025-04-16-low
#   - o3-mini-2025-01-31-high
#   - o3-mini-2025-01-31-low
#   - o3-mini-2025-01-31-medium
#   - o4-mini-2025-04-16-high
#   - o4-mini-2025-04-16-high_timeout-20m
#   - o4-mini-2025-04-16-high_timeout-60m
#   - o4-mini-2025-04-16-low
#   - o4-mini-2025-04-16-medium
#
# MISC_DRAGON (2 models):
#   - random
#   - sotckfish-lvl-1
#
# LLM_VS_LLM (11 models):
#   - 4-o_mini
#   - 4o_mini
#   - 4o_mini_messaed_player_names
#   - flash_2
#   - grok-3-mini-beta-high
#   - haiku_35
#   - o3-low
#   - o3-mini-low
#   - o3-mini-medium
#   - o4-mini-low
#   - o4-mini-medium
#
# ============================================================

# %%
# Analyze potential duplicates/variants
print("POTENTIAL MODEL NAME VARIANTS:")
print("=" * 60)

# Group similar names (simple heuristic based on common substrings)
model_groups = defaultdict(list)
for model in sorted(all_model_names):
    # Extract base model name (before @, -, or other separators)
    base_name = model.split('@')[0].split('-')[0].split('_')[0]
    model_groups[base_name].append(model)

# Show groups with multiple variants
for base_name, variants in model_groups.items():
    if len(variants) > 1:
        print(f"\n{base_name.upper()} variants:")
        for variant in variants:
            # Show which sources contain this variant
            sources = []
            for source, models in models_by_source.items():
                if variant in models:
                    sources.append(source)
            print(f"  - {variant} (sources: {', '.join(sources)})")

# Check for exact duplicates across sources
print("\n" + "=" * 60)
print("EXACT DUPLICATES ACROSS SOURCES:")
print("=" * 60)

for model in sorted(all_model_names):
    sources_with_model = []
    for source, models in models_by_source.items():
        if model in models:
            sources_with_model.append(source)
    
    if len(sources_with_model) > 1:
        print(f"{model}: {', '.join(sources_with_model)}")

print("\n" + "=" * 60)
# Out:
# POTENTIAL MODEL NAME VARIANTS:
# ============================================================
#
# 3X variants:
#   - 3x-o4-mini-2025-04-16-low_41mini-t03 (sources: dragon_vs_llm)
#   - 3x-o4-mini-2025-04-16-low_o4-mini-2025-04-16-medium (sources: dragon_vs_llm)
#
# 4O variants:
#   - 4o_mini (sources: llm_vs_llm)
#   - 4o_mini_messaed_player_names (sources: llm_vs_llm)
#
# AMAZON.NOVA variants:
#   - amazon.nova-lite-v1 (sources: refined)
#   - amazon.nova-pro-v1 (sources: refined)
#
# CLAUDE variants:
#   - claude-3-7-sonnet-20250219-thinking-budget-10000 (sources: dragon_refined, dragon_vs_llm)
#   - claude-3-7-sonnet-20250219-thinking-budget-5000 (sources: dragon_refined, dragon_vs_llm)
#   - claude-v3-5-haiku (sources: refined)
#   - claude-v3-5-sonnet-v1 (sources: refined)
#   - claude-v3-5-sonnet-v2 (sources: refined)
#   - claude-v3-7-sonnet (sources: refined)
#   - claude-v3-7-sonnet-thinking_10000 (sources: refined)
#   - claude-v3-7-sonnet-thinking_1024 (sources: refined)
#   - claude-v3-7-sonnet-thinking_2048 (sources: refined)
#   - claude-v3-7-sonnet-thinking_5000 (sources: refined)
#   - claude-v3-haiku (sources: refined)
#   - claude-v3-opus (sources: refined)
#   - claude-v4-opus (sources: refined)
#   - claude-v4-opus-thinking_16000 (sources: refined)
#   - claude-v4-sonnet (sources: refined)
#   - claude-v4-sonnet-thinking_16000 (sources: refined)
#
# DEEPSEEK variants:
#   - deepseek-chat-v3 (sources: refined)
#   - deepseek-chat-v3-0324 (sources: refined)
#   - deepseek-r1-distill-qwen-14b@q8_0 (sources: refined)
#   - deepseek-r1-distill-qwen-32b@q4_k_m (sources: refined)
#   - deepseek-reasoner-r1 (sources: refined)
#
# GEMINI variants:
#   - gemini-1.5-flash-001 (sources: refined)
#   - gemini-1.5-pro-preview-0409 (sources: refined)
#   - gemini-2.0-flash-001 (sources: refined)
#   - gemini-2.0-flash-exp (sources: refined)
#   - gemini-2.0-flash-lite-001 (sources: refined)
#   - gemini-2.0-flash-lite-preview-02-05 (sources: refined)
#   - gemini-2.0-flash-thinking-exp-01-21 (sources: refined)
#   - gemini-2.0-flash-thinking-exp-1219 (sources: refined)
#   - gemini-2.5-flash (sources: refined)
#   - gemini-2.5-pro (sources: refined)
#   - gemini-2.5-pro-preview-03-25 (sources: refined)
#   - gemini-2.5-pro-preview-05-06 (sources: refined)
#   - gemini-25pro-t03_mini41-t00_mini41-t03 (sources: dragon_vs_llm)
#
# GEMMA variants:
#   - gemma-2-27b-it@q6_k_l (sources: refined)
#   - gemma-2-9b-it-8bit (sources: refined)
#   - gemma-3-12b-it@iq4_xs (sources: refined)
#   - gemma-3-12b-it@q8_0 (sources: refined)
#   - gemma-3-27b-it@iq4_xs (sources: refined)
#
# GPT variants:
#   - gpt-35-turbo-0125 (sources: refined)
#   - gpt-35-turbo-0301 (sources: refined)
#   - gpt-35-turbo-0613 (sources: refined)
#   - gpt-35-turbo-1106 (sources: refined)
#   - gpt-4-0613 (sources: refined)
#   - gpt-4-32k-0613 (sources: refined)
#   - gpt-4-turbo-2024-04-09 (sources: refined)
#   - gpt-4.1-2025-04-14 (sources: refined)
#   - gpt-4.1-mini-2025-04-14 (sources: refined)
#   - gpt-4.1-nano-2025-04-14 (sources: refined)
#   - gpt-4.5-preview-2025-02-27 (sources: refined)
#   - gpt-4o-2024-05-13 (sources: refined)
#   - gpt-4o-2024-08-06 (sources: refined)
#   - gpt-4o-2024-11-20 (sources: refined)
#   - gpt-4o-mini-2024-07-18 (sources: refined)
#   - gpt-5-2025-08-07-low (sources: refined)
#   - gpt-5-chat-2025-08-07 (sources: refined)
#   - gpt-5-mini-2025-08-07-high (sources: refined)
#   - gpt-5-mini-2025-08-07-low (sources: refined)
#   - gpt-5-mini-2025-08-07-medium (sources: refined)
#   - gpt-5-nano-2025-08-07-high (sources: refined, dragon_refined)
#   - gpt-5-nano-2025-08-07-low (sources: refined, dragon_refined)
#   - gpt-5-nano-2025-08-07-medium (sources: refined, dragon_refined)
#   - gpt-oss-120b-high (sources: refined)
#   - gpt-oss-120b-low (sources: refined)
#   - gpt-oss-120b-medium (sources: refined)
#   - gpt-oss-20b-high (sources: refined)
#   - gpt-oss-20b-low (sources: refined)
#   - gpt-oss-20b-medium (sources: refined)
#
# GROK variants:
#   - grok-2-1212 (sources: refined)
#   - grok-3-beta (sources: refined)
#   - grok-3-mini-beta (sources: refined)
#   - grok-3-mini-beta-high (sources: refined, dragon_refined, dragon_vs_llm, llm_vs_llm)
#   - grok-3-mini-beta-low (sources: refined)
#   - grok-3-mini-fast-beta-high (sources: dragon_refined, dragon_vs_llm)
#
# LLAMA variants:
#   - llama-2-7b-chat (sources: refined)
#   - llama-3-70b-instruct-awq (sources: refined)
#   - llama-3.1-tulu-3-8b@q8_0 (sources: refined)
#   - llama-3.3-70b (sources: refined)
#   - llama-4-scout-cerebras (sources: refined)
#
# MISTRAL variants:
#   - mistral-nemo-12b-instruct-2407 (sources: refined)
#   - mistral-small-24b-instruct-2501@q4_k_m (sources: refined)
#   - mistral-small-instruct-2409 (sources: refined)
#
# NON variants:
#   - non-gemini-25pro-t03_mini41-t00_mini41-t03 (sources: refined)
#   - non-haiku35-t07_haiku35-t10_haiku35-t03 (sources: refined)
#   - non-r1-t03_mini41-t10_mini41-t03 (sources: refined)
#   - non_gpt-4.1-mini-2025-04-14_t00_t07_t03 (sources: refined)
#
# O1 variants:
#   - o1-2024-12-17 (sources: dragon_refined)
#   - o1-2024-12-17-low (sources: refined)
#   - o1-2024-12-17-medium (sources: refined)
#   - o1-mini-2024-09-12 (sources: refined, dragon_refined)
#   - o1-preview-2024-09-12 (sources: refined)
#
# O3 variants:
#   - o3-2025-04-16-low (sources: refined, dragon_refined, dragon_vs_llm)
#   - o3-2025-04-16-medium (sources: refined)
#   - o3-2025-04-16-medium_timeout-60m (sources: dragon_refined)
#   - o3-low (sources: llm_vs_llm)
#   - o3-mini-2025-01-31-high (sources: dragon_refined, dragon_vs_llm)
#   - o3-mini-2025-01-31-low (sources: refined, dragon_refined, dragon_vs_llm)
#   - o3-mini-2025-01-31-medium (sources: refined, dragon_refined, dragon_vs_llm)
#   - o3-mini-low (sources: llm_vs_llm)
#   - o3-mini-medium (sources: llm_vs_llm)
#
# O4 variants:
#   - o4-mini-2025-04-16-high (sources: refined, dragon_refined, dragon_vs_llm)
#   - o4-mini-2025-04-16-high_timeout-20m (sources: dragon_refined, dragon_vs_llm)
#   - o4-mini-2025-04-16-high_timeout-60m (sources: dragon_refined, dragon_vs_llm)
#   - o4-mini-2025-04-16-low (sources: refined, dragon_refined, dragon_vs_llm)
#   - o4-mini-2025-04-16-medium (sources: refined, dragon_refined, dragon_vs_llm)
#   - o4-mini-low (sources: llm_vs_llm)
#   - o4-mini-medium (sources: llm_vs_llm)
#
# QWEN variants:
#   - qwen-3-235b-a22b-instruct-2507 (sources: refined)
#   - qwen-max-2025-01-25 (sources: refined)
#   - qwen-plus-2025-01-25 (sources: refined)
#   - qwen-turbo-2024-11-01 (sources: refined)
#
# QWEN2.5 variants:
#   - qwen2.5-14b-instruct-1m (sources: refined)
#   - qwen2.5-14b-instruct@q8_0 (sources: refined)
#   - qwen2.5-72b-instruct (sources: refined)
#   - qwen2.5-7b-instruct-1m (sources: refined)
#
# QWEN3 variants:
#   - qwen3-14b@iq4_xs-thinking (sources: refined)
#   - qwen3-30b-a3b-thinking-2507@q4_k_m (sources: refined)
#   - qwen3-32b-cerebras-thinking (sources: refined)
#   - qwen3-4b-thinking-2507@q8 (sources: refined)
#
# QWQ variants:
#   - qwq-32b (sources: refined)
#   - qwq-32b-preview@q4_k_m (sources: refined)
#
# ============================================================
# EXACT DUPLICATES ACROSS SOURCES:
# ============================================================
# claude-3-7-sonnet-20250219-thinking-budget-10000: dragon_refined, dragon_vs_llm
# claude-3-7-sonnet-20250219-thinking-budget-5000: dragon_refined, dragon_vs_llm
# gpt-5-nano-2025-08-07-high: refined, dragon_refined
# gpt-5-nano-2025-08-07-low: refined, dragon_refined
# gpt-5-nano-2025-08-07-medium: refined, dragon_refined
# grok-3-mini-beta-high: refined, dragon_refined, dragon_vs_llm, llm_vs_llm
# grok-3-mini-fast-beta-high: dragon_refined, dragon_vs_llm
# o1-mini-2024-09-12: refined, dragon_refined
# o3-2025-04-16-low: refined, dragon_refined, dragon_vs_llm
# o3-mini-2025-01-31-high: dragon_refined, dragon_vs_llm
# o3-mini-2025-01-31-low: refined, dragon_refined, dragon_vs_llm
# o3-mini-2025-01-31-medium: refined, dragon_refined, dragon_vs_llm
# o4-mini-2025-04-16-high: refined, dragon_refined, dragon_vs_llm
# o4-mini-2025-04-16-high_timeout-20m: dragon_refined, dragon_vs_llm
# o4-mini-2025-04-16-high_timeout-60m: dragon_refined, dragon_vs_llm
# o4-mini-2025-04-16-low: refined, dragon_refined, dragon_vs_llm
# o4-mini-2025-04-16-medium: refined, dragon_refined, dragon_vs_llm
#
# ============================================================

# %%
# Create a standardization mapping
# This will be a manual mapping that we can adjust based on the analysis above
model_name_mapping = {
    # Add mappings here based on the analysis
    # Example: 'variant_name': 'standard_name'
}

# Function to standardize model names
def standardize_model_name(name):
    """Apply standardization mapping to model names"""
    return model_name_mapping.get(name, name)

# Apply standardization to all rows
standardized_rows = []
for row in ROWS_OUT:
    new_row = row.copy()
    new_row['player_white'] = standardize_model_name(row['player_white'])
    new_row['player_black'] = standardize_model_name(row['player_black'])
    standardized_rows.append(new_row)

print(f"Applied standardization mapping to {len(standardized_rows)} rows")
print(f"Mapping rules: {len(model_name_mapping)}")

# Check if any standardization was applied
changes_made = sum(1 for i, row in enumerate(ROWS_OUT) 
                  if (standardized_rows[i]['player_white'] != row['player_white'] or 
                      standardized_rows[i]['player_black'] != row['player_black']))

print(f"Rows with changes: {changes_made}")

# Use standardized rows for output
ROWS_OUT = standardized_rows
# Out:
# Applied standardization mapping to 346 rows
# Mapping rules: 0
# Rows with changes: 0

# %% [markdown]
# ## Final Output

# %%
# Ensure deterministic ordering by player_white, then player_black
ROWS_OUT.sort(key=lambda x: (x["player_white"].lower(), x["player_black"].lower()))

# Write to CSV (overwrite)
with WIN_RATES_CSV.open("w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=HEADER)
    writer.writeheader()
    writer.writerows(ROWS_OUT)

print(f"\nTotal rows written to {WIN_RATES_CSV}: {len(ROWS_OUT)}")
print(f"- From refined.csv: {len(ROWS_OUT) - dragon_vs_llm_count - misc_dragon_count - llm_vs_llm_count}")
print(f"- From dragon_vs_llm: {dragon_vs_llm_count}")
print(f"- From misc/dragon: {misc_dragon_count}")
print(f"- From llm_vs_llm: {llm_vs_llm_count}")
# Out:
# Total rows written to win_rates.csv: 346
# - From refined.csv: 287
# - From dragon_vs_llm: 28
# - From misc/dragon: 20
# - From llm_vs_llm: 11

# %%
preview_win_rates_csv(WIN_RATES_CSV)

PREVIEW_ROWS = CURR_ROWS
CURR_ROWS = len(rows)

print(f"Total rows: {CURR_ROWS}, rows added: {CURR_ROWS - PREVIEW_ROWS}")

# Show breakdown by data source
source_counts = Counter(row[8] for row in rows)  # source is column 8
print(f"\nBreakdown by source:")
for source, count in source_counts.items():
    print(f"- {source}: {count} rows")

# Show breakdown by player types
dragon_rows = sum(1 for row in rows if 'dragon-lvl-' in row[0] or 'dragon-lvl-' in row[1])
random_rows = sum(1 for row in rows if 'random' in row[0] or 'random' in row[1])
stockfish_rows = sum(1 for row in rows if 'stockfish' in row[0] or 'stockfish' in row[1])
llm_only_rows = len(rows) - dragon_rows - random_rows - stockfish_rows

print(f"\nBreakdown by player types:")
print(f"- Rows with Dragon: {dragon_rows}")
print(f"- Rows with Random: {random_rows}")
print(f"- Rows with Stockfish: {stockfish_rows}")
print(f"- LLM vs LLM only: {llm_only_rows}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 preview_win_rates_csv(WIN_RATES_CSV)
#       3 PREVIEW_ROWS = CURR_ROWS
#       4 CURR_ROWS = len(rows)
#
# NameError: name 'preview_win_rates_csv' is not defined
